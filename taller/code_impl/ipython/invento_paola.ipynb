# %%
import sys
sys.path.insert(0, '../python/')
import classes as cl
import pandas as pd
import numpy as np
from datetime import datetime, date, time
import time
import matplotlib as plt

def OVECMRR(y, L, P, it, avg_error, r, n, alpha):
    it2, l = y.shape
    new_beta = False            # Get a new beta condition
    Y_true = np.zeros([it, l])  # Out of sample true value
    Y_pred = np.zeros([it, l])  # Out of sample forecasting
    mape = np.zeros([it, l])     # In-sample mape
    m = cl.Matrix()

    start_time = time.time()

    for i in range(it):
        #sys.stdout.write("\r{0}%".format((float(i + 1) / it) * 100))
        #sys.stdout.flush()

        y_i = y[i:i + L]

        if i == 0:
            beta = m.get_johansen(y_i.as_matrix(), P, r)
            A, B = m.vec_matrix(y_i, P, beta.evecr)
        else:
            A, B = m.vec_matrix_online(A, B, y_i, P, beta.evecr)
            Y_true[i,:] = B[-1,:]
            Y_pred[i,:] = np.dot(A[-1,:], x)

        x = m.ridge_regression(A, B, alpha)

        Ax = np.dot(A, x)
        residuals = B - Ax

        y_true = B[-n:]
        y_pred = Ax[-n:]

        mape[i,:] = m.MAPE(y_true, y_pred)

        if (np.average(mape[i,:]) > avg_error):
            beta = m.get_johansen(y_i.as_matrix(), P)
            r = beta.r
            A = m.vec_matrix_update(A, y_i, P, beta.evecr)
            x = m.ridge_regression(A, B, alpha)

    o_mape = m.MAPE(Y_true, Y_pred)  # Out-of-Sample MAPE
    return y_true, y_pred, Y_true, Y_pred, mape, o_mape, time.time() - start_time

def OVECM(y, L, P, it, avg_error, r, n):
    # SLAAR Using MAPE
    it2, l = y.shape
    # it = 100                            # Number of iterations
    # r = 1                               # Number of cointegration relations
    # n = 10                              # Number of instances to calculate MAPE
    new_beta = False
    # avg_error = 120

    Y_true = np.zeros([it, l])          # Out of sample 
    Y_pred = np.zeros([it, l])          # Forecasting
    mape = np.zeros([it, l])            # In-sample mape

    m = cl.Matrix()
    start_time = time.time()
    for i in range(it):
        #sys.stdout.write("\r{0}%".format((float(i + 1) / it) * 100))
        #sys.stdout.flush()
        y_i = y[i:i + L]

        if i == 0:
            beta = m.get_johansen(y_i.as_matrix(), P, r)
            A, B = m.vec_matrix(y_i, P, beta.evecr)
        else:
            A, B = m.vec_matrix_online(A, B, y_i, P, beta.evecr)
            Y_true[i,:] = B[-1,:]
            Y_pred[i,:] = np.dot(A[-1,:], x)

        x, residuals, rank, s = np.linalg.lstsq(A, B)
        Ax = np.dot(A, x)
        residuals = B - Ax

        y_true = B[-n:]
        y_pred = Ax[-n:]

        mape[i,:] = m.MAPE(y_true, y_pred)
        try:
            avg_mape = np.average(mape[i,:])
        except:
            print i, i+L
            
        if avg_mape > avg_error:
            try:
                beta = m.get_johansen(y_i.as_matrix(), P)
            except:
                print "Unexpected error"
                print i, i + L

            r = beta.r
            A = m.vec_matrix_update(A, y_i, P, beta.evecr)
            x, residuals, rank, s = np.linalg.lstsq(A, B)

    # Out-of-Sample MAPE
    o_mape = m.MAPE(Y_true, Y_pred)
    return y_true, y_pred, Y_true, Y_pred, mape, o_mape, time.time() - start_time

def sign_counter(true, pred):
    counter = 0
    for i in range(len(true)):
        #print "True:", true[i], "Sign", np.sign(true[i]), "Pred:", pred[i], "Sign", np.sign(pred[i])
        if np.sign(true[i]) == np.sign(pred[i]):
            counter += 1
    return counter

prefix = '../data_csv/data_ticks/august_11/'
reader = cl.Reader([prefix+'EURUSD.csv', prefix+'GBPUSD.csv', prefix+'USDCHF.csv', prefix+'USDJPY.csv'])

ticks = reader.load_dukascopy()
nt_1 = next(ticks)
nt_2 = next(ticks)
nt_3 = next(ticks)
nt_4 = next(ticks)

print "done"
# Out:
# done

# %%
r = 0
L = 1000
P = 4
it = 100
n = 100
avg_error = 0
alpha = 0.1

# %%
ticks_resampled = reader.resample([nt_1, nt_2, nt_3, nt_4], '30s')
t_1, t_2, t_3, t_4 = next(ticks_resampled), next(ticks_resampled), next(ticks_resampled), next(ticks_resampled)

ask = reader.merge([t_1, t_2, t_3, t_4], 'Ask')
ask_norm = reader.normalize(ask, [2, 3])
ask_norm = ask_norm.astype(float32)

y = ask_norm
y_true, y_pred, Y_true, Y_pred, mape, o_mape, etime = OVECM(y, L, P, it, avg_error, r, n)
rr_y_true, rr_y_pred, rr_Y_true, rr_Y_pred, rr_mape, rr_o_mape, rr_etime = OVECMRR(y, L, P, it, avg_error, r, n, alpha)

print ""
print o_mape
print rr_o_mape
# Out:
# [ 153.86262464  193.17856715  175.78881567  178.12611701]
# [ 115.85327469  102.82428923  101.30318564   98.72391139]

# %%
m = cl.Matrix()

pylab.rcParams['figure.figsize'] = (17.0, 15.0)
it1 = 10
#l = 4
l = 1

mape_list = []
rr_mape_list = []

print "Y_true OVECM"
print "------------"
for j in range(1,l+1):
    ax = subplot(4,1,j)
    ax.plot(range(it1-1),Y_true[1:it1,j-1],'r--',label='True '+y.columns[j-1])
    ax.plot(range(it1-1),Y_pred[1:it1,j-1],'b-',label='Pred '+y.columns[j-1])
    
    mape_serie = []
    
    print "Stock", y.columns[j-1]
    print "MAPE", m.MAPE(Y_true[1:it1,j-1], Y_pred[1:it1,j-1])
    print "Total equal signs", sign_counter(Y_true[1:it1,j-1], Y_pred[1:it1,j-1])
    print "-------------------"
    for i in range(1, len(Y_true[1:it1,j-1]) + 1):
        ma = m.MAPE(np.array([Y_true[i,j-1]]), np.array([Y_pred[i,j-1]]))
        mape_serie.append(ma[0])
        print "Y_true", Y_true[i,j-1], "\tY_pred", Y_pred[i,j-1], "\t", ma

    mape_list.append(mape_serie)    
    
print "--------------------------------------------------------------------------------"
        
print "Y_true RR OVECMRR"
print "-----------------"
for j in range(1,l+1):
    ax = subplot(4,1,j)
    ax.plot(range(it1-1),rr_Y_true[1:it1,j-1],'r--',label='True '+y.columns[j-1])
    ax.plot(range(it1-1),rr_Y_pred[1:it1,j-1],'m-',label='Pred '+y.columns[j-1])
    
    rr_mape_serie = []
    
    print "Stock", y.columns[j-1]
    print "MAPE", m.MAPE(rr_Y_true[1:it1,j-1], rr_Y_pred[1:it1,j-1])
    print "Total equal signs", sign_counter(rr_Y_true[1:it1,j-1], rr_Y_pred[1:it1,j-1])
    print "-------------------"
    for i in range(1, len(rr_Y_true[1:it1,j-1]) + 1):
        ma = m.MAPE(np.array([rr_Y_true[i,j-1]]), np.array([rr_Y_pred[i,j-1]]))
        rr_mape_serie.append(ma[0])
        print "Y_true", rr_Y_true[i,j-1], "\tY_pred", rr_Y_pred[i,j-1], "\t", ma

    rr_mape_list.append(rr_mape_serie)
# Out:
# Y_true OVECM
# ------------
# Stock EURUSD_Ask
# MAPE [ 191.122656]
# Total equal signs 5
# -------------------
# Y_true 1.08480453491e-05 	Y_pred -1.30537431591e-05 	[ 220.33267505]
# Y_true 1.22785568237e-05 	Y_pred
# 1.3086219333e-05 	[ 6.57782931]
# Y_true -2.38418579102e-07 	Y_pred 2.11577889709e-06 	[ 987.42198912]
# Y_true -2.7060508728e-05 	Y_pred -9.2469179103e-07 	[ 96.58287359]
# Y_true 3.54051589966e-05 	Y_pred -7.81848069603e-06 	[ 122.08288543]
# Y_true 7.5101852417e-05 	Y_pred 1.19869185877e-05 	[ 84.03911728]
# Y_true -0.000107526779175 	Y_pred 2.04164133945e-05 	[ 118.98728256]
# Y_true -4.3511390686e-05 	Y_pred -4.41667475711e-05 	[ 1.50617315]
# Y_true -2.4676322937e-05 	Y_pred -4.30032341569e-06 	[ 82.57307855]
# --------------------------------------------------------------------------------
# Y_true RR OVECMRR
# -----------------
# Stock EURUSD_Ask
# MAPE [ 161.28276465]
# Total equal signs 5
# -------------------
# Y_true 1.08480453491e-05 	Y_pred -1.78278991519e-06 	[ 116.43420412]
# Y_true 1.22785568237e-05 	Y_pred -1.78178795743e-06 	[ 114.51137933]
# Y_true -2.38418579102e-07 	Y_pred -1.74721162852e-06 	[ 632.83367224]
# Y_true -2.7060508728e-05 	Y_pred -1.78527049771e-06 	[ 93.40267208]
# Y_true 3.54051589966e-05 	Y_pred -1.871323839e-06 	[ 105.28545526]
# Y_true 7.5101852417e-05 	Y_pred -1.86147610573e-06 	[ 102.47860212]
# Y_true -0.000107526779175 	Y_pred -1.739824584e-06 	[ 98.38196159]
# Y_true -4.3511390686e-05 	Y_pred -1.83037145395e-06 	[ 95.79335106]
# Y_true -2.4676322937e-05 	Y_pred -1.8695808681e-06 	[ 92.42358405]

# %%
#Plot mape as serie
plot(np.array(mape_list[0]))
plot(np.array(rr_mape_list[0]))
